# %% [markdown]
# # Лабораторная работа 1
#
# ## Pandas
#
# Выполнил: 6133-010402D, Коршиков Владислав Игоревич

# %% [markdown]
# ## Импортируем DataFrame, содержащий все машины из Gran Turismo 6

# %% [markdown]
# 1 Импортируем DataFrame, содержащий все машины из Gran Turismo 6

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
gran_turismo = pd.read_csv("/content/drive/MyDrive/gran_turismo_gt6.csv")

# %%
gran_turismo.head()
# Out:
#      brand                             model car_type  \
# 0  AC Cars                       427 S/C '66   Street
# 1      AEM                             S2000    Tuned
# 2   Abarth  1500 Biposto Bertone B.A.T 1 '52   Street
# 3   Abarth                           500 '09   Street
# 4   Abarth                  Grande Punto '09   Street
#
#                                              img_url      price drive     hp  \
# 0  https://www.kudosprime.com/gt6/images/cars/gt6...   423200.0    FR  478.0
# 1  https://www.kudosprime.com/gt6/images/cars/gt6...   100000.0    FR  430.0
# 2  https://www.kudosprime.com/gt6/images/cars/gt6...  3500000.0    FR   72.0
# 3  https://www.kudosprime.com/gt6/images/cars/gt6...    29500.0    FF  133.0
# 4  https://www.kudosprime.com/gt6/images/cars/gt6...    27000.0    FF  153.0
#
#    weight  torque             w_kg
# 0  1311.0   651.0    272 to ? W/Kg
# 1  1155.0   495.0  278 to 345 W/Kg
# 2   870.0     NaN   62 to 250 W/Kg
# ...

# %% [markdown]
# Целевым значением для датафрейма является car_type, который разделяет датасет на два кластера street(уличные гонки) и race(трековые гонки), для машин, класс которых определить невозможно, ставится маркер tuned.
# Датасет можно найти здесь: https://www.kaggle.com/prasertk/gran-turismo-6-cars/version/1

# %%
#опишем данные
#они содержат два типа данных категориальный(представлен object) и вещественный (представлен float64). Большая часть объектов имеют тип object.
datatypes = gran_turismo.dtypes
print(datatypes)
# Out:
# brand        object
# model        object
# car_type     object
# img_url      object
# price       float64
# drive        object
# hp          float64
# weight      float64
# torque      float64
# w_kg         object
# dtype: object

# %%
# Некоторые данные в выборке отсутствуют
gran_turismo.isnull().sum()
# Out:
# brand         0
# model         0
# car_type      0
# img_url       0
# price         5
# drive         2
# hp           43
# weight       57
# torque      224
# w_kg          0
# dtype: int64

# %% [markdown]
# ## 2. Выполните с датафреймом следующие операции (многие операции можно совершить не одним способом, используйте все известные вам способы, поищите/придумайте новые способы) :

# %%
#2.1 вывод таблицы
gran_turismo
# Out:
#            brand                             model car_type  \
# 0        AC Cars                       427 S/C '66   Street
# 1            AEM                             S2000    Tuned
# 2         Abarth  1500 Biposto Bertone B.A.T 1 '52   Street
# 3         Abarth                           500 '09   Street
# 4         Abarth                  Grande Punto '09   Street
# ...          ...                               ...      ...
# 1265  Volkswagen                    Scirocco R '10   Street
# 1266  Volkswagen                     W12 Nardo '01   Street
# 1267       Volvo                240 GLT Estate '88   Street
# 1268       Volvo                  C30 R-Design '09   Street
# 1269       Volvo                 S60 T-5 Sport '03   Street
#
#                                                 img_url      price drive  \
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...   423200.0    FR
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...   100000.0    FR
# ...

# %%
#2.2 выводим первые n(7) элементов таблицы двумя способами
gran_turismo[:7]
# Out:
#      brand                             model car_type  \
# 0  AC Cars                       427 S/C '66   Street
# 1      AEM                             S2000    Tuned
# 2   Abarth  1500 Biposto Bertone B.A.T 1 '52   Street
# 3   Abarth                           500 '09   Street
# 4   Abarth                  Grande Punto '09   Street
# 5    Acura                 CL 3.2 Type-S '01   Street
# 6    Acura                 CL 3.2 Type-S '03   Street
#
#                                              img_url      price drive     hp  \
# 0  https://www.kudosprime.com/gt6/images/cars/gt6...   423200.0    FR  478.0
# 1  https://www.kudosprime.com/gt6/images/cars/gt6...   100000.0    FR  430.0
# 2  https://www.kudosprime.com/gt6/images/cars/gt6...  3500000.0    FR   72.0
# 3  https://www.kudosprime.com/gt6/images/cars/gt6...    29500.0    FF  133.0
# 4  https://www.kudosprime.com/gt6/images/cars/gt6...    27000.0    FF  153.0
# ...

# %%
gran_turismo.head(7)
# Out:
#      brand                             model car_type  \
# 0  AC Cars                       427 S/C '66   Street
# 1      AEM                             S2000    Tuned
# 2   Abarth  1500 Biposto Bertone B.A.T 1 '52   Street
# 3   Abarth                           500 '09   Street
# 4   Abarth                  Grande Punto '09   Street
# 5    Acura                 CL 3.2 Type-S '01   Street
# 6    Acura                 CL 3.2 Type-S '03   Street
#
#                                              img_url      price drive     hp  \
# 0  https://www.kudosprime.com/gt6/images/cars/gt6...   423200.0    FR  478.0
# 1  https://www.kudosprime.com/gt6/images/cars/gt6...   100000.0    FR  430.0
# 2  https://www.kudosprime.com/gt6/images/cars/gt6...  3500000.0    FR   72.0
# 3  https://www.kudosprime.com/gt6/images/cars/gt6...    29500.0    FF  133.0
# 4  https://www.kudosprime.com/gt6/images/cars/gt6...    27000.0    FF  153.0
# ...

# %%
#2.3 выведем последние n(7) элементов таблицы двумя способами
gran_turismo.tail(7)
# Out:
#            brand                                   model car_type  \
# 1263  Volkswagen  Scirocco GT24 15th Anniversary Edition     Race
# 1264  Volkswagen            Scirocco GT24 Base Model '08     Race
# 1265  Volkswagen                          Scirocco R '10   Street
# 1266  Volkswagen                           W12 Nardo '01   Street
# 1267       Volvo                      240 GLT Estate '88   Street
# 1268       Volvo                        C30 R-Design '09   Street
# 1269       Volvo                       S60 T-5 Sport '03   Street
#
#                                                 img_url      price drive  \
# 1263  https://www.kudosprime.com/gt6/images/cars/gt6...   450000.0    FF
# 1264  https://www.kudosprime.com/gt6/images/cars/gt6...   420000.0    FF
# 1265  https://www.kudosprime.com/gt6/images/cars/gt6...    51500.0    FF
# 1266  https://www.kudosprime.com/gt6/images/cars/gt6...  1250000.0    MR
# ...

# %%
gran_turismo[-7:]
# Out:
#            brand                                   model car_type  \
# 1263  Volkswagen  Scirocco GT24 15th Anniversary Edition     Race
# 1264  Volkswagen            Scirocco GT24 Base Model '08     Race
# 1265  Volkswagen                          Scirocco R '10   Street
# 1266  Volkswagen                           W12 Nardo '01   Street
# 1267       Volvo                      240 GLT Estate '88   Street
# 1268       Volvo                        C30 R-Design '09   Street
# 1269       Volvo                       S60 T-5 Sport '03   Street
#
#                                                 img_url      price drive  \
# 1263  https://www.kudosprime.com/gt6/images/cars/gt6...   450000.0    FF
# 1264  https://www.kudosprime.com/gt6/images/cars/gt6...   420000.0    FF
# 1265  https://www.kudosprime.com/gt6/images/cars/gt6...    51500.0    FF
# 1266  https://www.kudosprime.com/gt6/images/cars/gt6...  1250000.0    MR
# ...

# %%
#2.4 применим метод .describe()
gran_turismo.describe()
# Out:
#               price           hp       weight       torque
# count  1.265000e+03  1227.000000  1213.000000  1046.000000
# mean   4.599464e+05   311.413203  1223.604287   362.771511
# std    1.597771e+06   193.016438   324.001464   219.297234
# min    5.000000e+03    12.000000    63.000000    12.000000
# 25%    2.909000e+04   173.000000  1035.000000   192.000000
# 50%    5.900000e+04   276.000000  1230.000000   319.000000
# 75%    3.750000e+05   444.000000  1438.000000   490.000000
# max    2.000000e+07  1509.000000  3500.000000  2033.000000

# %%
#2.5 считывание значения конкретной ячейки (с конкретным индексом из конкретной колонки: model, 7) всеми известными вам способами
print(gran_turismo['model'][7])
print(gran_turismo.get('model')[7])
print(gran_turismo.loc[7]['model'])
print(gran_turismo.iloc[7]['model'])
# Out:
# DN-X '02
# DN-X '02
# DN-X '02
# DN-X '02

# %%
#2.6 фильтрация строк по диапазону индекса 12-18
gran_turismo[12:18]
# Out:
#          brand                   model car_type  \
# 12       Acura         NSX CONCEPT '13   Street
# 13       Acura           NSX Coupe '97   Street
# 14       Acura     NSX LM Race Car '91     Race
# 15       Acura          RSX Type-S '04   Street
# 16  Alfa Romeo  147 2.0 TWIN SPARK '02   Street
# 17  Alfa Romeo             147 GTA '02   Street
#
#                                               img_url      price drive     hp  \
# 12  https://www.kudosprime.com/gt6/images/cars/gt6...  1000000.0   4WD    NaN
# 13  https://www.kudosprime.com/gt6/images/cars/gt6...    89130.0    MR  290.0
# 14  https://www.kudosprime.com/gt6/images/cars/gt6...   205000.0    MR  363.0
# 15  https://www.kudosprime.com/gt6/images/cars/gt6...    24740.0    FF  200.0
# 16  https://www.kudosprime.com/gt6/images/cars/gt6...    30590.0    FF  148.0
# 17  https://www.kudosprime.com/gt6/images/cars/gt6...    48040.0    FF  246.0
#
#     weight  torque             w_kg
# 12     NaN     NaN      ? to ? W/Kg
# ...

# %%
#2.7 фильтрация набора данных по какому-либо условию
gran_turismo_bmw = gran_turismo.loc[(gran_turismo['brand'] == 'BMW') & (gran_turismo['price'] > 70000), ['car_type', 'drive', 'weight']]
gran_turismo_bmw
# Out:
#     car_type drive  weight
# 107     Race    FR  1140.0
# 109   Street    FR  1240.0
# 111     Race    FR  1245.0
# 112   Street    FR  1465.0
# 113   Street    FR  1570.0
# 114   Street    FR  1385.0
# 115   Street    FR  1655.0
# 116   Street    FR  1625.0
# 117     Race    FR  1245.0
# 118     Race    FR  1245.0
# 119   Street    FR  1350.0
# 120     Race    FR  1120.0
# 121   Street    FR  1497.0
# 122   Street    FR  1497.0
# 123   Street    FR  1715.0
# 124   Street    FR  1855.0
# 125     Race    MR   950.0
# 126     Race    MR   900.0
# 127     Race    FR  1180.0
# 129     Race    FR  1190.0
# 131   Street    FR  1610.0
# 132   Street    FR  1580.0

# %%
#2.8. Удалим пустые значения и проверим успешность удаления: 
gran_turismo_2=gran_turismo
gran_turismo_new=gran_turismo_2.dropna(axis=0)
gran_turismo_new.isnull().sum()
# Out:
# brand       0
# model       0
# car_type    0
# img_url     0
# price       0
# drive       0
# hp          0
# weight      0
# torque      0
# w_kg        0
# dtype: int64

# %%
gran_turismo_new
# Out:
#            brand               model car_type  \
# 0        AC Cars         427 S/C '66   Street
# 1            AEM               S2000    Tuned
# 3         Abarth             500 '09   Street
# 4         Abarth    Grande Punto '09   Street
# 5          Acura   CL 3.2 Type-S '01   Street
# ...          ...                 ...      ...
# 1265  Volkswagen      Scirocco R '10   Street
# 1266  Volkswagen       W12 Nardo '01   Street
# 1267       Volvo  240 GLT Estate '88   Street
# 1268       Volvo    C30 R-Design '09   Street
# 1269       Volvo   S60 T-5 Sport '03   Street
#
#                                                 img_url      price drive  \
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...   423200.0    FR
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...   100000.0    FR
# 3     https://www.kudosprime.com/gt6/images/cars/gt6...    29500.0    FF
# 4     https://www.kudosprime.com/gt6/images/cars/gt6...    27000.0    FF
# ...

# %%
#2.9. создание нового поля вычисленного на основе значений других полей:

# %%
# 2.9.1 через выражение на базе имеющихся колонок,
# Попробуем представить вес машины(weight) в фунтах(weight_f).
gran_turismo_new_2 = gran_turismo_new.assign(weight_f = gran_turismo_new.weight * 2.2)

# %%
gran_turismo_new_2
# Out:
#            brand               model car_type  \
# 0        AC Cars         427 S/C '66   Street
# 1            AEM               S2000    Tuned
# 3         Abarth             500 '09   Street
# 4         Abarth    Grande Punto '09   Street
# 5          Acura   CL 3.2 Type-S '01   Street
# ...          ...                 ...      ...
# 1265  Volkswagen      Scirocco R '10   Street
# 1266  Volkswagen       W12 Nardo '01   Street
# 1267       Volvo  240 GLT Estate '88   Street
# 1268       Volvo    C30 R-Design '09   Street
# 1269       Volvo   S60 T-5 Sport '03   Street
#
#                                                 img_url      price drive  \
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...   423200.0    FR
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...   100000.0    FR
# 3     https://www.kudosprime.com/gt6/images/cars/gt6...    29500.0    FF
# 4     https://www.kudosprime.com/gt6/images/cars/gt6...    27000.0    FF
# ...

# %%
#2.9.2 через DataFrame.apply Найдём соотношение веса к хитпоинтам

gtr = gran_turismo_new.copy()
gtr.drop(["brand", "model", "car_type", "img_url", "price", "drive",	"torque",	"w_kg"], axis=1, inplace=True)

# %%
gtr
# Out:
#          hp  weight
# 0     478.0  1311.0
# 1     430.0  1155.0
# 3     133.0  1035.0
# 4     153.0  1240.0
# 5     260.0  1592.0
# ...     ...     ...
# 1265  252.0  1410.0
# 1266  574.0  1300.0
# 1267  127.0  1890.0
# 1268  227.0  1430.0
# 1269  246.0  1550.0
#
# [1031 rows x 2 columns]

# %%
gtr.apply(np.sum, axis=0)
# Out:
# hp         302447.0
# weight    1285929.0
# dtype: float64

# %%
#2.9.3 через Series.apply
gtr_2 = gran_turismo_price.copy()
gtr_2['weight_f'] = gtr_2['weight'].apply(lambda x: round(2.2*gran_turismo_price['weight'].mean(),0))

# %%
gtr_2
# Out:
#            brand                    model car_type  \
# 0       Daihatsu     Midget II D type '98   Street
# 1          Honda              TODAY G '85   Street
# 2          Honda        LIFE STEP VAN '72   Street
# 3     Mitsubishi       MIRAGE 1400GLX '78   Street
# 4          Honda  CIVIC 1500 3door CX '79   Street
# ...          ...                      ...      ...
# 1026        Ford     Mark IV Race Car '67     Race
# 1027     Ferrari               330 P4 '67     Race
# 1028      Jaguar         XJ13 Chrome Line     Race
# 1029        Ford        GT40 Race Car '69     Race
# 1030      Jaguar                 XJ13 '66     Race
#
#                                                 img_url       price drive  \
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...      5740.0    FR
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...      6700.0    FF
# 2     https://www.kudosprime.com/gt6/images/cars/gt6...      8800.0    FF
# ...

# %%
#2.10 сортировка по какому-либо из полей
gran_turismo_new.sort_values('price')
# Out:
#           brand                    model car_type  \
# 220    Daihatsu     Midget II D type '98   Street
# 432       Honda              TODAY G '85   Street
# 375       Honda        LIFE STEP VAN '72   Street
# 761  Mitsubishi       MIRAGE 1400GLX '78   Street
# 338       Honda  CIVIC 1500 3door CX '79   Street
# ..          ...                      ...      ...
# 286        Ford     Mark IV Race Car '67     Race
# 238     Ferrari               330 P4 '67     Race
# 461      Jaguar         XJ13 Chrome Line     Race
# 284        Ford        GT40 Race Car '69     Race
# 460      Jaguar                 XJ13 '66     Race
#
#                                                img_url       price drive  \
# 220  https://www.kudosprime.com/gt6/images/cars/gt6...      5740.0    FR
# 432  https://www.kudosprime.com/gt6/images/cars/gt6...      6700.0    FF
# 375  https://www.kudosprime.com/gt6/images/cars/gt6...      8800.0    FF
# ...

# %%
#2.11 вычислить несколько статистик по колонкам (используйте встроенные агрегатные функции — любые на выбор)
gran_turismo_new.groupby(['brand'])[['price','hp']].agg(['min', 'max', 'mean'])
# Out:
#                price                               hp
#                  min        max           mean    min    max        mean
# brand
# AC Cars     423200.0   423200.0  423200.000000  478.0  478.0  478.000000
# AEM         100000.0   100000.0  100000.000000  430.0  430.0  430.000000
# Abarth       27000.0    29500.0   28250.000000  133.0  153.0  143.000000
# Acura        24740.0    94440.0   54121.428571  195.0  290.0  252.142857
# Alfa Romeo   28500.0  1250000.0  170436.250000  108.0  582.0  235.312500
# ...              ...        ...            ...    ...    ...         ...
# Toyota        9800.0  1950000.0  180108.441558   44.0  789.0  221.402597
# Triumph      17200.0    17200.0   17200.000000   71.0   71.0   71.000000
# Vauxhall     17960.0  1250000.0  346838.571429   89.0  454.0  235.428571
# Volkswagen   15000.0  1250000.0  166010.869565   25.0  574.0  190.478261
# Volvo        15920.0    42000.0   31166.666667  127.0  246.0  200.000000
#
# [103 rows x 6 columns]

# %%
#2.12 .value_counts()  #return Series
print(gran_turismo_new['hp'].value_counts(sort=True))
print(gran_turismo_new[['price','brand']].value_counts(sort=True))
# Out:
# 276.0    119
# 246.0     31
# 493.0     22
# 63.0      22
# 197.0     22
#         ...
# 601.0      1
# 74.0       1
# 435.0      1
# 389.0      1
# 127.0      1
# Name: hp, Length: 323, dtype: int64
# price     brand
# 950000.0  Nissan        8
# 750000.0  Nissan        8
# 29980.0   Mitsubishi    7
# 750000.0  Honda         6
# 18980.0   Mazda         5
#                        ..
# 38860.0   MG            1
# 38900.0   Isuzu         1
# 16000.0   Scion         1
# 38910.0   Volkswagen    1
# 5740.0    Daihatsu      1
# Length: 821, dtype: int64

# %%
#2.13 Вывод уникальных значений колонки через .unique()
gran_turismo['brand'].unique()
# Out:
# array(['AC Cars', 'AEM', 'Abarth', 'Acura', 'Alfa Romeo', 'Alpine',
#        'Amuse', 'Art Morrison', 'Aston Martin', 'Audi', 'Autobacs',
#        'Autobianchi', 'Ayrton Senna', 'BLITZ', 'BMW', 'Bentley',
#        'Bugatti', 'Buick', 'Cadillac', 'Callaway', 'Caterham',
#        'Chaparral', 'Chevrolet', 'Chrysler', 'Citroën', 'Cizeta', 'DMC',
#        'Daihatsu', 'DeltaWing', 'Dodge', 'Dome', 'Eagle', 'Ferrari',
#        'Fiat', 'Fisker', 'Ford', 'Gillet', 'Gran Turismo',
#        'Grand Touring Garage', 'HKS', 'HPA Motorsports',
#        'High End Performance', 'Holden', 'Hommell', 'Honda', 'Hudson',
#        'Hyundai', 'Infiniti', 'Isuzu', 'Jaguar', 'Jay leno', 'KTM',
#        'Lamborghini', 'Lancia', 'Land Rover', 'Lexus',
#        'Light Car Company', 'Lister', 'Lotus', 'MG', 'MINI', 'Marcos',
#        'Maserati', 'Mazda', 'McLaren', 'Mercedes-Benz', 'Mercury',
#        "Mine's", 'Mitsubishi', 'Monster Sport', 'Mugen', 'NISMO',
# ...

# %%
#2.14 Удалите текущий индекс и создайте новый индекс на базе новой колонки, которая для этого лучше всего подходит
gran_turismo_price = gran_turismo_new.sort_values('price').reset_index()
del gran_turismo_price['index']
gran_turismo_price
# Out:
#            brand                    model car_type  \
# 0       Daihatsu     Midget II D type '98   Street
# 1          Honda              TODAY G '85   Street
# 2          Honda        LIFE STEP VAN '72   Street
# 3     Mitsubishi       MIRAGE 1400GLX '78   Street
# 4          Honda  CIVIC 1500 3door CX '79   Street
# ...          ...                      ...      ...
# 1026        Ford     Mark IV Race Car '67     Race
# 1027     Ferrari               330 P4 '67     Race
# 1028      Jaguar         XJ13 Chrome Line     Race
# 1029        Ford        GT40 Race Car '69     Race
# 1030      Jaguar                 XJ13 '66     Race
#
#                                                 img_url       price drive  \
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...      5740.0    FR
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...      6700.0    FF
# 2     https://www.kudosprime.com/gt6/images/cars/gt6...      8800.0    FF
# ...

# %% [markdown]
# 3 Продемонстрировать работу .groupby, на основе группировок в groupby вычисляете агрегатные функции по одной или нескольким колонкам. Какую информацию о данных вы получили, выполнив данную операцию? Запишите ответ в комментариях.

# %%
#Видим, что среднее значение price сильно влияет на значение hp
print(gran_turismo_price.groupby('price')['hp'].mean())
# Out:
# price
# 5740.0          31.0
# 6700.0          31.0
# 8800.0          30.0
# 9220.0          78.0
# 9570.0          84.0
#                ...
# 3750000.0      420.0
# 4500000.0      374.0
# 6000000.0     1193.0
# 15000000.0     339.0
# 20000000.0     483.6
# Name: hp, Length: 582, dtype: float64

# %% [markdown]
# 4 Решейпинг данных 1Dto2D с помощью .pivot (можно подать на вход результаты агрегатов, полученных ранее через .groupby (сгруппировать по двум полям), либо прекрасно заходит сюда данные из SQL сгруппированные предварительно по 2-м полям). Какую информацию о данных вы получили, выполнив данную операцию? Запишите ответ в комментариях.

# %%
#Дадим характеристику автомобилей, принадлежащих различным типам. В силу того, что большинство машин имеют тип street, в таблице отображается только она
gran_turismo_price_2 = gran_turismo_price.pivot_table(index='car_type', columns='model')
gran_turismo_price_2
# Out:
#                      hp                                                \
# model    106 Rallye '03 106 S16 '03 11 OS (L10A) '67 11 OS (L10B) '68
# car_type
# Race                NaN         NaN              NaN              NaN
# Street            102.0       116.0            108.0            126.0
# Tuned               NaN         NaN              NaN              NaN
#
#                                                                       \
# model    117 COUPE '68 1200 '66 120d '04 120i '04 1300 Coupe 9 S '70
# car_type
# Race               NaN      NaN      NaN      NaN                NaN
# Street           118.0     34.0    161.0    148.0              108.0
# Tuned              NaN      NaN      NaN      NaN                NaN
#
#                          ...  weight                                     \
# model    135i Coupé '07  ...  xA '03  xB '03 éfini RX-7 Type R (FD) '91
# car_type                 ...
# ...

# %%
gran_turismo_price_2.keys()
# Out:
# MultiIndex([(    'hp',               '106 Rallye '03'),
#             (    'hp',                  '106 S16 '03'),
#             (    'hp',             '11 OS (L10A) '67'),
#             (    'hp',             '11 OS (L10B) '68'),
#             (    'hp',                '117 COUPE '68'),
#             (    'hp',                     '1200 '66'),
#             (    'hp',                     '120d '04'),
#             (    'hp',                     '120i '04'),
#             (    'hp',           '1300 Coupe 9 S '70'),
#             (    'hp',               '135i Coupé '07'),
#             ...
#             ('weight',                       'xA '03'),
#             ('weight',                       'xB '03'),
#             ('weight',   'éfini RX-7 Type R (FD) '91'),
#             ('weight',   'éfini RX-7 Type R (FD) '93'),
#             ('weight', 'éfini RX-7 Type R-S (FD) '95'),
#             ('weight',  'éfini RX-7 Type RS (FD) '96'),
# ...

# %%
gran_turismo_price_2.index
# Out:
# Index(['Race', 'Street', 'Tuned'], dtype='object', name='car_type')

# %% [markdown]
# 5 Решейпинг 1Dto2D данных соединённый с группировкой / агрегацией (одним словом — сводная таблица): .pivot_table. Группируем только по категориальным полям или числовым, если уверены, что значений немного! Если значений много, можете вначале из загрубить (см. (2.9.) либо (7)).
# Перед тем как выполнять задание сформулируйте вопрос, на который собираетесь получить ответ с помощью сводной таблицы. Запишите этот вопрос в комментариях. Какую информацию о данных вы в результате получили?
# https://pbpython.com/pandas-pivot-table-explained.html

# %%
#Как отличается цена на машины разных типов в зависимости от производителя?
#Мы получили следующие материалы, отображение которых не совсем корректно ввиду особенностей датасета
gran_turismo_new_5 = gran_turismo_new.pivot_table(index='brand', columns='car_type', values=['price'],
                       aggfunc='mean')
gran_turismo_new_5
# Out:
#                    price
# car_type            Race         Street     Tuned
# brand
# AC Cars              NaN  423200.000000       NaN
# AEM                  NaN            NaN  100000.0
# Abarth               NaN   28250.000000       NaN
# Acura                NaN   54121.428571       NaN
# Alfa Romeo  1.250000e+06   98465.333333       NaN
# ...                  ...            ...       ...
# Toyota      7.234118e+05   26172.500000       NaN
# Triumph              NaN   17200.000000       NaN
# Vauxhall    1.125000e+06   35574.000000       NaN
# Volkswagen  3.208333e+05  111367.647059       NaN
# Volvo                NaN   31166.666667       NaN
#
# [103 rows x 3 columns]

# %% [markdown]
# 6 Посчитать квантили распределения какого-либо вещественного признака (с помощью numpy.quantile или numpy.percentile)

# %%
np.quantile(gran_turismo_new['price'], q=.5)
# Out:
# 44200.0

# %% [markdown]
# 7 Посчитать гистограмму какого-либо вещественного признака (с помощью numpy.histogram). Значения гистограммы можете использовать как вариант в качестве загрубленного числового признака для заданий (4) или (5).

# %%
np.histogram(gran_turismo_price['price'])
# Out:
# (array([1015,    8,    2,    0,    0,    0,    0,    1,    0,    5]),
#  array([5.7400000e+03, 2.0051660e+06, 4.0045920e+06, 6.0040180e+06,
#         8.0034440e+06, 1.0002870e+07, 1.2002296e+07, 1.4001722e+07,
#         1.6001148e+07, 1.8000574e+07, 2.0000000e+07]))

# %% [markdown]
# 8 Получить DataFrame с MultiIndex любым способом: через конструктор (в документации увидите множество видов конструкторов для создания MultiIndex с нуля), через read_sql / read_csv / read_excel, read_*, через pivot_table, через groupby или иными способами.

# %%
gran_turismo_new_6 = gran_turismo_price.groupby(by=['weight', 'torque']).max()
gran_turismo_new_6
# Out:
#                            brand                                  model  \
# weight torque
# 63.0   12.0         Ayrton Senna                DAP Racing Kart #17 '80
# 369.0  122.0            Caterham                    Seven Fireblade '02
# 385.0  29.0               Subaru                                360 '58
# 390.0  118.0   Light Car Company                             Rocket '07
# 455.0  216.0        Ayrton Senna  West Surrey Racing, 1983 Ayrton Senna
# ...                          ...                                    ...
# 2248.0 440.0           Chevrolet                                SSR '03
# 2268.0 644.0           Chevrolet                      Silverado SST '02
# 2390.0 508.0                 Ram         1500 LARAMIE Hemi Quad Cab '04
# 2404.0 1300.0             Fisker                     Karma EcoSport '12
# 3500.0 2033.0           Jay leno                           Tank Car '03
#
#               car_type                                            img_url  \
# ...

# %% [markdown]
# 9 Переставить местами уровни индекса

# %%
gran_turismo_new_6.swaplevel(i=0 , j=1).sort_index()
# Out:
#                       brand                       model car_type  \
# torque weight
# 12.0   63.0    Ayrton Senna     DAP Racing Kart #17 '80     Race
# 24.0   560.0          Mazda        Carol 360 Deluxe '62   Street
# 28.0   605.0          Honda           LIFE STEP VAN '72   Street
# 29.0   385.0         Subaru                     360 '58   Street
#        475.0          Honda                    N360 '67   Street
# ...                     ...                         ...      ...
# 1200.0 930.0        Peugeot  908 HDi FAP Base Model '10     Race
# 1254.0 1888.0       Bugatti             Veyron 16.4 '13   Street
# 1300.0 2404.0        Fisker          Karma EcoSport '12   Street
# 1356.0 1851.0      Jay leno    1966 Oldsmobile Toronado    Tuned
# 2033.0 3500.0      Jay leno                Tank Car '03   Street
#
#                                                          img_url      price  \
# torque weight
# 12.0   63.0    https://www.kudosprime.com/gt6/images/cars/gt6...   100000.0
# ...

# %% [markdown]
# 10 Транспонировать таблицу (или создать новую другую) с MultiIndex

# %%
gran_turismo_new_6.T
# Out:
# weight                                               63.0    \
# torque                                               12.0
# brand                                          Ayrton Senna
# model                               DAP Racing Kart #17 '80
# car_type                                               Race
# img_url   https://www.kudosprime.com/gt6/images/cars/gt6...
# price                                              100000.0
# drive                                                    MR
# hp                                                     30.0
# w_kg                                        349 to 349 W/Kg
#
# weight                                               369.0   \
# torque                                               122.0
# brand                                              Caterham
# model                                   Seven Fireblade '02
# car_type                                             Street
# img_url   https://www.kudosprime.com/gt6/images/cars/gt6...
# ...

# %% [markdown]
# 11 Удалить один из уровней индекса или добавить новый уровень индекса (можно инициализированный константой)

# %%
gran_turismo_new_7 = gran_turismo_new_6.copy()
gran_turismo_new_7.reset_index(level=1, inplace=False)
# Out:
#         torque              brand                                  model  \
# weight
# 63.0      12.0       Ayrton Senna                DAP Racing Kart #17 '80
# 369.0    122.0           Caterham                    Seven Fireblade '02
# 385.0     29.0             Subaru                                360 '58
# 390.0    118.0  Light Car Company                             Rocket '07
# 455.0    216.0       Ayrton Senna  West Surrey Racing, 1983 Ayrton Senna
# ...        ...                ...                                    ...
# 2248.0   440.0          Chevrolet                                SSR '03
# 2268.0   644.0          Chevrolet                      Silverado SST '02
# 2390.0   508.0                Ram         1500 LARAMIE Hemi Quad Cab '04
# 2404.0  1300.0             Fisker                     Karma EcoSport '12
# 3500.0  2033.0           Jay leno                           Tank Car '03
#
#        car_type                                            img_url      price  \
# ...

# %% [markdown]
# 12 Продемонстировать работу .merge

# %%
df_left = gran_turismo_price.iloc[:, :len(gran_turismo_price.keys())//2]
df_right = gran_turismo_price.iloc[:, len(gran_turismo_price.keys())//2+1:]

# %%
df_left
# Out:
#            brand                    model car_type  \
# 0       Daihatsu     Midget II D type '98   Street
# 1          Honda              TODAY G '85   Street
# 2          Honda        LIFE STEP VAN '72   Street
# 3     Mitsubishi       MIRAGE 1400GLX '78   Street
# 4          Honda  CIVIC 1500 3door CX '79   Street
# ...          ...                      ...      ...
# 1026        Ford     Mark IV Race Car '67     Race
# 1027     Ferrari               330 P4 '67     Race
# 1028      Jaguar         XJ13 Chrome Line     Race
# 1029        Ford        GT40 Race Car '69     Race
# 1030      Jaguar                 XJ13 '66     Race
#
#                                                 img_url       price
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...      5740.0
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...      6700.0
# 2     https://www.kudosprime.com/gt6/images/cars/gt6...      8800.0
# 3     https://www.kudosprime.com/gt6/images/cars/gt6...      9220.0
# ...

# %%
pd.merge(df_left, df_right,left_index=True, right_index=True)
# Out:
#            brand                    model car_type  \
# 0       Daihatsu     Midget II D type '98   Street
# 1          Honda              TODAY G '85   Street
# 2          Honda        LIFE STEP VAN '72   Street
# 3     Mitsubishi       MIRAGE 1400GLX '78   Street
# 4          Honda  CIVIC 1500 3door CX '79   Street
# ...          ...                      ...      ...
# 1026        Ford     Mark IV Race Car '67     Race
# 1027     Ferrari               330 P4 '67     Race
# 1028      Jaguar         XJ13 Chrome Line     Race
# 1029        Ford        GT40 Race Car '69     Race
# 1030      Jaguar                 XJ13 '66     Race
#
#                                                 img_url       price     hp  \
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...      5740.0   31.0
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...      6700.0   31.0
# 2     https://www.kudosprime.com/gt6/images/cars/gt6...      8800.0   30.0
# ...

# %% [markdown]
# 13 Продемонстрировать работу с .concat или append

# %%
gt1 = gran_turismo_price.iloc[:len(gran_turismo_price)//2]
gt2 = gran_turismo_price.iloc[len(gran_turismo_price)//2+1:]

# %%
gt1
# Out:
#           brand                                              model car_type  \
# 0      Daihatsu                               Midget II D type '98   Street
# 1         Honda                                        TODAY G '85   Street
# 2         Honda                                  LIFE STEP VAN '72   Street
# 3    Mitsubishi                                 MIRAGE 1400GLX '78   Street
# 4         Honda                            CIVIC 1500 3door CX '79   Street
# ..          ...                                                ...      ...
# 510       Mazda                        éfini RX-7 Type RZ (FD) '93   Street
# 511      Nissan                               Fairlady Z (Z34) '08   Street
# 512      Toyota                                       SUPRA RZ '97   Street
# 513      Nissan  Fairlady Z 300ZX Version R TwinTurbo 2by2 (Z32...   Street
# 514      Nissan                               300ZX 2by2 (Z32) '98   Street
#
# ...

# %%
pd.concat([gt1, gt2])
# Out:
#            brand                    model car_type  \
# 0       Daihatsu     Midget II D type '98   Street
# 1          Honda              TODAY G '85   Street
# 2          Honda        LIFE STEP VAN '72   Street
# 3     Mitsubishi       MIRAGE 1400GLX '78   Street
# 4          Honda  CIVIC 1500 3door CX '79   Street
# ...          ...                      ...      ...
# 1026        Ford     Mark IV Race Car '67     Race
# 1027     Ferrari               330 P4 '67     Race
# 1028      Jaguar         XJ13 Chrome Line     Race
# 1029        Ford        GT40 Race Car '69     Race
# 1030      Jaguar                 XJ13 '66     Race
#
#                                                 img_url       price drive  \
# 0     https://www.kudosprime.com/gt6/images/cars/gt6...      5740.0    FR
# 1     https://www.kudosprime.com/gt6/images/cars/gt6...      6700.0    FF
# 2     https://www.kudosprime.com/gt6/images/cars/gt6...      8800.0    FF
# ...

# %% [markdown]
# 14 Проитерировать dataframe построчно .iterrows(). Выполните что-то имеющее смысл внутри цикла

# %%
#Выведем из dataset_5 образование с наибольшим временем разговора
gran_turismo_new_9 = pd.DataFrame(columns=['brand','car_type'])
for i, row in gran_turismo_new_5.iterrows():
    gran_turismo_new_9.loc[gran_turismo_new_9.shape[0]] = [row.idxmax()[1], round(row.max(),2)]
gran_turismo_new_9.set_index(gran_turismo_new_5.index)
# Out:
#              brand    car_type
# brand
# AC Cars     Street   423200.00
# AEM          Tuned   100000.00
# Abarth      Street    28250.00
# Acura       Street    54121.43
# Alfa Romeo    Race  1250000.00
# ...            ...         ...
# Toyota        Race   723411.76
# Triumph     Street    17200.00
# Vauxhall      Race  1125000.00
# Volkswagen    Race   320833.33
# Volvo       Street    31166.67
#
# [103 rows x 2 columns]
